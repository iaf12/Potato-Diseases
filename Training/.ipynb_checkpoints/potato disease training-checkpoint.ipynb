# %%
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import models, layers

# %%
Image_size = 256
Batch_size = 32
Channels = 3
Epochs = 12

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    'Potato Database/',
    shuffle= True,
    image_size= (Image_size, Image_size),
    batch_size= Batch_size
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
# It will show only the batches..

len(dataset)
# Out:
# 68

# %%
# the answer is around the total imagese of the dataset

68 * 32
# Out:
# 2176

# %%
for image_batch, label_batch in dataset.take(1):
    print(image_batch.shape)
    print(label_batch.numpy())
# Out:
# (32, 256, 256, 3)
# [0 1 0 1 1 0 1 0 0 0 1 1 0 1 2 1 1 1 1 1 1 1 0 0 1 0 0 0 1 0 1 1]

# %%
plt.figure(figsize=(10, 10))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(class_names[label_batch[i]])
        plt.axis('off')

# %% [markdown]
# train set = 80 %
#
# validation set = 10 %
#
# test set = 10 %

# %%
train_size = 0.8
len(dataset) * train_size
# Out:
# 54.400000000000006

# %%
train_ds = dataset.take(54)
len(train_ds)
# Out:
# 54

# %%
test_ds = dataset.skip(54)
len(test_ds)
# Out:
# 14

# %%
val_size = 0.1
len(dataset) * val_size
# Out:
# 6.800000000000001

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 6

# %%
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 8

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds), len(val_ds), len(test_ds)
# Out:
# (54, 6, 8)

# %% [markdown]
# i have to see the below lecture from codebasics.... optimized cpu an gpu

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(Image_size, Image_size),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip('horizontal_and_vertical'),
    layers.experimental.preprocessing.RandomRotation(0.2)
])

# %%
input_images = (Batch_size, Image_size, Image_size, Channels)
# (32, 256, 256, 3)
n_classes=3

model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    
    layers.Conv2D(32, (3,3), activation='relu', input_shape=input_images),
    layers.MaxPooling2D(2,2),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(2,2),
    
    layers.Conv2D(128, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(2,2),
    #layers.Dropout(rate=0.4),
    
    layers.Conv2D(128, kernel_size=(3,3), activation='relu'),
    #layers.MaxPooling2D(2,2),
    #layers.Dropout(rate=0.4),    
  
    layers.Conv2D(256, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Dropout(rate=0.4),
    
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(2,2),
    
    layers.Flatten(),
    layers.Dense(1024, activation='relu'),
    layers.Dense(512, activation='relu'),
    layers.Dense(n_classes, activation='softmax')
])

model.build(input_shape=input_images)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 128)       147584
#
#  conv2d_4 (Conv2D)           (None, 26, 26, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  dropout (Dropout)           (None, 13, 13, 256)       0
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 64)        147520
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 1024)              1639424
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 2,849,283
# Trainable params: 2,849,283
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer= 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    validation_data= val_ds,
    epochs=Epochs,
    batch_size=Batch_size,
    verbose=1
)
# Out:
# Epoch 1/12
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 54/54 [==============================] - 25s 265ms/step - loss: 0.9009 - accuracy: 0.4907 - val_loss: 1.0499 - val_accuracy: 0.4479
# Epoch 2/12
# 54/54 [==============================] - 11s 204ms/step - loss: 0.7641 - accuracy: 0.6146 - val_loss: 0.9184 - val_accuracy: 0.5885
# Epoch 3/12
# 54/54 [==============================] - 11s 195ms/step - loss: 0.6046 - accuracy: 0.7390 - val_loss: 0.5290 - val_accuracy: 0.7656
# Epoch 4/12
# 54/54 [==============================] - 11s 198ms/step - loss: 0.4219 - accuracy: 0.8466 - val_loss: 0.2661 - val_accuracy: 0.8802
# Epoch 5/12
# 54/54 [==============================] - 11s 198ms/step - loss: 0.2664 - accuracy: 0.8993 - val_loss: 0.3358 - val_accuracy: 0.8854
# Epoch 6/12
# 54/54 [==============================] - 11s 195ms/step - loss: 0.2058 - accuracy: 0.9126 - val_loss: 0.3948 - val_accuracy: 0.8698
# Epoch 7/12
# 54/54 [==============================] - 10s 193ms/step - loss: 0.1971 - accuracy: 0.9288 - val_loss: 0.2887 - val_accuracy: 0.8802
# Epoch 8/12
# 54/54 [==============================] - 11s 196ms/step - loss: 0.2120 - accuracy: 0.9190 - val_loss: 0.3025 - val_accuracy: 0.9062
# Epoch 9/12
# 54/54 [==============================] - 11s 211ms/step - loss: 0.1736 - accuracy: 0.9427 - val_loss: 0.2495 - val_accuracy: 0.8958
# Epoch 10/12
# 54/54 [==============================] - 11s 202ms/step - loss: 0.0916 - accuracy: 0.9682 - val_loss: 1.0442 - val_accuracy: 0.7552
# Epoch 11/12
# 54/54 [==============================] - 11s 195ms/step - loss: 0.1457 - accuracy: 0.9491 - val_loss: 0.2072 - val_accuracy: 0.9219
# Epoch 12/12
# 54/54 [==============================] - 11s 195ms/step - loss: 0.1311 - accuracy: 0.9502 - val_loss: 0.4049 - val_accuracy: 0.8594

# %%
scores = model.evaluate(test_ds)
scores
# Out:
# 8/8 [==============================] - 2s 42ms/step - loss: 0.2814 - accuracy: 0.8867
# [0.2813832759857178, 0.88671875]

# %%
history

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
len(history.history['accuracy'])
# Out:
# 12

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(6,6))
plt.subplot(1, 2, 1)
plt.plot(range(Epochs), acc, label='Training Accuracy')
plt.plot(range(Epochs), val_acc, label='Validationg Accuracy')
plt.legend(loc='lower right')
plt.title('Training and validationg accuracy')
# Out:
# Text(0.5, 1.0, 'Training and validationg accuracy')

# %%
import numpy as np

for image_batch, label_batch in test_ds.take(1):
    first_image= image_batch[0].numpy().astype('uint8')
    first_label = label_batch[0].numpy()
    
    print('First image to predict : ')
    plt.imshow(first_image)
    print('Actual label', class_names[first_label])
    
    batch_prediction  = model.predict(image_batch)
    print((batch_prediction[0]))
    print(np.argmax(batch_prediction[0]))
# Out:
# First image to predict :
# Actual label Potato___Late_blight
# 1/1 [==============================] - 0s 200ms/step
# [0.11814985 0.87407637 0.00777375]
# 1

# %%
def predict(model, img):
    img_array =  tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0) # create a batch
    
    predictions = model.predict(img_array)
    
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(14, 14))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i+1)
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]
        
        plt.title(f'Actual: {actual_class}, \nPredicted: {predicted_class}, \nConfidence: {confidence}')
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.axis('off')
# Out:
# 1/1 [==============================] - 0s 358ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
